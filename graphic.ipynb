# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# vgg16_scnn_tusimple_20210224.pt
df = pd.read_csv('x_down1.csv', header = None).T[1140:1420]
# df = pd.read_csv('x_down1.csv', header = None).T[1230:1250]
df.plot()
# Out:
# <AxesSubplot: >

# %%
# vgg16_baseline_tusimple_20210223.pt
# df = pd.read_csv('x_down2.csv', header = None).T[1140:1420]
# df = pd.read_csv('x_down2.csv', header = None).T[1140:1450]
df = pd.read_csv('x_down2.csv', header = None).T[1100:1600]
df.plot()
# Out:
# <AxesSubplot: >

# %%
# resnet18_baseline_tusimple_20210215.pt
# df = pd.read_csv('x_down2.csv', header = None).T[1140:1420]
# df = pd.read_csv('x_down2.csv', header = None).T[1140:1450]
df = pd.read_csv('x_down2.csv', header = None).T[1100:1600]
df.plot()
# Out:
# <AxesSubplot: >

# %%
# resnet34_baseline_tusimple.pt
# df = pd.read_csv('x_down2.csv', header = None).T[1140:1420]
# df = pd.read_csv('x_down2.csv', header = None).T[1140:1450]
df = pd.read_csv('x_down_resnet34_baseline_tusimple.csv', header = None).T[1100:1600]
df.plot()
# Out:
# <AxesSubplot: >

# %%
# resnet50_baseline_tusimple_20210217.pt
# df = pd.read_csv('x_down2.csv', header = None).T[1140:1420]
# df = pd.read_csv('x_down2.csv', header = None).T[1140:1450]
df = pd.read_csv('x_down_resnet50_baseline_tusimple_20210217.csv', header = None).T[1100:1600]
df.plot()
# Out:
# <AxesSubplot: >

# %%
# resnet101_baseline_tusimple.pt
# df = pd.read_csv('x_down2.csv', header = None).T[1140:1420]
# df = pd.read_csv('x_down2.csv', header = None).T[1140:1450]
df = pd.read_csv('x_down_resnet101_baseline_tusimple.csv', header = None).T[1100:1600]
df.plot()
# Out:
# <AxesSubplot: >

# %%
# resnet34_bezierlanenet_culane_aug1b.pt
# df = pd.read_csv('x_down2.csv', header = None).T[1140:1420]
# df = pd.read_csv('x_down2.csv', header = None).T[1140:1450]
df = pd.read_csv('x_down_resnet34_bezierlanenet_culane_aug1b.csv', header = None).T[1100:1600]
df.plot()
# Out:
# <AxesSubplot: >

# %%
# resnet34_bezierlanenet_llamas_aug1b.pt
# df = pd.read_csv('x_down2.csv', header = None).T[1140:1420]
# df = pd.read_csv('x_down2.csv', header = None).T[1140:1450]
df = pd.read_csv('x_down_resnet34_bezierlanenet_llamas_aug1b.csv', header = None).T[1100:1600]
df.plot()
# Out:
# <AxesSubplot: >

# %%
# resnet34_bezierlanenet_tusimple_aug1b.pt
# df = pd.read_csv('x_down2.csv', header = None).T[1140:1420]
# df = pd.read_csv('x_down2.csv', header = None).T[1140:1450]
df = pd.read_csv('x_down_resnet34_bezierlanenet_tusimple_aug1b.csv', header = None).T[1100:1600]
df.plot()
# Out:
# <AxesSubplot: >

# %%
# vgg16_baseline_llamas_20210625.pt
# df = pd.read_csv('x_down2.csv', header = None).T[1140:1420]
# df = pd.read_csv('x_down2.csv', header = None).T[1140:1450]
df = pd.read_csv('x_down_vgg16_baseline_llamas_20210625.csv', header = None).T[1100:1600]
df.plot()
# Out:
# <AxesSubplot: >

# %%
# vresnet34_baseline_llamas.pt
# df = pd.read_csv('x_down2.csv', header = None).T[1140:1420]
# df = pd.read_csv('x_down2.csv', header = None).T[1140:1450]
df = pd.read_csv('x_down_resnet34_baseline_llamas.csv', header = None).T[1100:1600]
df.plot()
# Out:
# <AxesSubplot: >

# %%
# erfnet_baseline_llamas.pt
# df = pd.read_csv('x_down2.csv', header = None).T[1140:1420]
# df = pd.read_csv('x_down2.csv', header = None).T[1140:1450]
df = pd.read_csv('x_down_erfnet_baseline_llamas_20210625.csv', header = None).T[1100:1600]
df.plot()
# Out:
# <AxesSubplot: >

# %%
# resnet34_baseline_culane.pt
# df = pd.read_csv('x_down2.csv', header = None).T[1140:1420]
# df = pd.read_csv('x_down2.csv', header = None).T[1140:1450]
df = pd.read_csv('x_down_resnet34_baseline_culane_20210219.csv', header = None).T[1100:1600]
df.plot()
# Out:
# <AxesSubplot: >

# %%
# resnet101_baseline_culane.pt
# df = pd.read_csv('x_down2.csv', header = None).T[1140:1420]
# df = pd.read_csv('x_down2.csv', header = None).T[1140:1450]
df = pd.read_csv('x_down_resnet101_baseline_culane_20210312.csv', header = None).T[1100:1600]
df.plot()
# Out:
# <AxesSubplot: >

# %%
# erfnet_baseline_culane.pt
# df = pd.read_csv('x_down2.csv', header = None).T[1140:1420]
# df = pd.read_csv('x_down2.csv', header = None).T[1140:1450]
df = pd.read_csv('x_down_erfnet_baseline_culane_20210204.csv', header = None).T[1100:1600]
df.plot()
# Out:
# <AxesSubplot: >

# %%
# resnet34_scnn_tusimple_20210424.pt
# df = pd.read_csv('x_down2.csv', header = None).T[1140:1420]
# df = pd.read_csv('x_down2.csv', header = None).T[1140:1450]
df = pd.read_csv('x_down_resnet34_scnn_tusimple_20210424.csv', header = None).T[1100:1600]
df.plot()
# Out:
# <AxesSubplot: >

# %%
# resnet34_scnn-aug_tusimple_20210723.pt
# df = pd.read_csv('x_down2.csv', header = None).T[1140:1420]
# df = pd.read_csv('x_down2.csv', header = None).T[1140:1450]
df = pd.read_csv('x_down_resnet34_scnn-aug_tusimple_20210723.csv', header = None).T[1100:1600]
df.plot()
# Out:
# <AxesSubplot: >

# %%
# resnet50_scnn_tusimple_20210217.pt
# df = pd.read_csv('x_down2.csv', header = None).T[1140:1420]
# df = pd.read_csv('x_down2.csv', header = None).T[1140:1450]
df = pd.read_csv('x_down_resnet50_scnn_tusimple_20210217.csv', header = None).T[1100:1600]
df.plot()
# Out:
# <AxesSubplot: >

# %%
# resnet101_scnn_tusimple_20210218.pt
# df = pd.read_csv('x_down_resnet101_scnn_tusimple_20210218.csv', header = None).T[0:1840]
# df = pd.read_csv('x_down_resnet101_scnn_tusimple_20210218.csv', header = None).T[1280:1290]
# df = pd.read_csv('x_down_resnet101_scnn_tusimple_20210218.csv', header = None).T[1450:1550]
df = pd.read_csv('x_down_resnet101_scnn_tusimple_20210218.csv', header = None).T[1100:1600]
df.plot()
# Out:
# <AxesSubplot: >

# %%
# erfnet_scnn_tusimple_20210202.pt
# df = pd.read_csv('x_down2.csv', header = None).T[1140:1420]
# df = pd.read_csv('x_down2.csv', header = None).T[1140:1450]
df = pd.read_csv('x_down_erfnet_scnn_tusimple_20210202.csv', header = None).T[1100:1600]
df.plot()
# Out:
# <AxesSubplot: >

# %%
# resnet34_resa_tusimple_20211019.pt
# df = pd.read_csv('x_down2.csv', header = None).T[1140:1420]
# df = pd.read_csv('x_down2.csv', header = None).T[1140:1450]
df = pd.read_csv('x_down_resnet34_resa_tusimple_20211019.csv', header = None).T[1100:1600]
df.plot()
# Out:
# <AxesSubplot: >

# %%
# resnet50_resa_tusimple_20211019.pt
# df = pd.read_csv('x_down2.csv', header = None).T[1140:1420]
# df = pd.read_csv('x_down2.csv', header = None).T[1140:1450]
df = pd.read_csv('x_down_resnet50_resa_tusimple_20211019.csv', header = None).T[1100:1600]
df.plot()
# Out:
# <AxesSubplot: >

# %%
# resnet101_resa_tusimple_20211019.pt
# df = pd.read_csv('x_down2.csv', header = None).T[1140:1420]
# df = pd.read_csv('x_down2.csv', header = None).T[1140:1450]
df = pd.read_csv('x_down_resnet101_resa_tusimple_20211019.csv', header = None).T[1100:1600]
df.plot()
# Out:
# <AxesSubplot: >

# %%
# erfnet_resa_tusimple_20220422.pt
# df = pd.read_csv('x_down2.csv', header = None).T[1140:1420]
# df = pd.read_csv('x_down2.csv', header = None).T[1140:1450]
df = pd.read_csv('x_down_erfnet_resa_tusimple_20220422.csv', header = None).T[1100:1600]
df.plot()
# Out:
# <AxesSubplot: >

# %%
# resnet18s_lstr-aug_tusimple_20210629.pt
# df = pd.read_csv('x_down2.csv', header = None).T[1140:1420]
# df = pd.read_csv('x_down2.csv', header = None).T[1140:1450]
df = pd.read_csv('x_down_resnet18s_lstr-aug_tusimple_20210629.csv', header = None).T[1100:1600]
df.plot()
# Out:
# <AxesSubplot: >

# %%
plt.close("all")
df.plot()
